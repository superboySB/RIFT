# %% [markdown]
# ## Main Evaluation Results

# %%
run tools/plot/plot_eval_result.py
# Out:
# ===== Results for pdm_lite =====
# +-----------------+-------------------+----------------------+------------------------+-----------------------+-------------+--------------+--------------+-----------------+--------------+-------------+-------------+-------------+-------------+-------------+-------------+--------------+
# |     Method      | Driving Score (↑) | Route Completion (↑) | Infraction Penalty (↑) | Ego Blocked Ratio (↓) |   ORR (↓)   |    UC (%)    |   CPK (↓)    |     RP (↑)      | SW speed (↑) | WD speed(↓) | SW acc (↑)  |  RTTC (↑)   |   ACT (↑)   | Acc (m/s²)  | Speed (m/s) | Jerk (m/s³)  |
# +-----------------+-------------------+----------------------+------------------------+-----------------------+-------------+--------------+--------------+-----------------+--------------+-------------+-------------+-------------+-------------+-------------+-------------+--------------+
# ...

# %% [markdown]
# ## Acceleration and Speed Distribution

# %%
run tools/plot/plot_distribution.py
# Out:
# >> Successfully saved plot to assets
